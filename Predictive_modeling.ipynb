# %% [markdown]
# <h2>Data Loading</h2>

# %%
import kagglehub, os
import pandas as pd
dir = kagglehub.dataset_download('deltasierra452/airline-pax-satisfaction-survey')

print('Data source import complete.')
data = pd.read_csv(os.path.join(dir,os.listdir(dir)[0]))
data
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/deltasierra452/airline-pax-satisfaction-survey?dataset_version_number=1...
# 100%|██████████| 2.16M/2.16M [00:00<00:00, 43.3MB/s]
# Extracting files...
# Data source import complete.
#             SR      id  Gender      Customer_Type  Age   Type_of_Travel  \
# 0            0   70172    Male     Loyal Customer   13  Personal Travel
# 1            1    5047    Male  disloyal Customer   25  Business travel
# 2            2  110028  Female     Loyal Customer   26  Business travel
# 3            3   24026  Female     Loyal Customer   25  Business travel
# 4            4  119299    Male     Loyal Customer   61  Business travel
# ...        ...     ...     ...                ...  ...              ...
# 103899  103899   94171  Female  disloyal Customer   23  Business travel
# 103900  103900   73097    Male     Loyal Customer   49  Business travel
# 103901  103901   68825    Male  disloyal Customer   30  Business travel
# 103902  103902   54173  Female  disloyal Customer   22  Business travel
# 103903  103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight_Distance  Inflight_wifi_service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival_time_convenient  ...  Inflight_entertainment  \
# 0                                       4  ...                       5
# 1                                       2  ...                       1
# 2                                       2  ...                       5
# 3                                       5  ...                       2
# 4                                       3  ...                       3
# ...                                   ...  ...                     ...
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival_Delay_in_Minutes             satisfaction
# 0                           18.0  neutral or dissatisfied
# 1                            6.0  neutral or dissatisfied
# 2                            0.0                satisfied
# 3                            9.0  neutral or dissatisfied
# 4                            0.0                satisfied
# ...                          ...                      ...
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [103904 rows x 25 columns]

# %%
#menggunakan environment kaggle
import pandas as pd
data=pd.read_csv("/kaggle/input/airline-pax-satisfaction-survey/airline_clnd.csv")
data
# Out:
#             SR      id  Gender      Customer_Type  Age   Type_of_Travel  \
# 0            0   70172    Male     Loyal Customer   13  Personal Travel
# 1            1    5047    Male  disloyal Customer   25  Business travel
# 2            2  110028  Female     Loyal Customer   26  Business travel
# 3            3   24026  Female     Loyal Customer   25  Business travel
# 4            4  119299    Male     Loyal Customer   61  Business travel
# ...        ...     ...     ...                ...  ...              ...
# 103899  103899   94171  Female  disloyal Customer   23  Business travel
# 103900  103900   73097    Male     Loyal Customer   49  Business travel
# 103901  103901   68825    Male  disloyal Customer   30  Business travel
# 103902  103902   54173  Female  disloyal Customer   22  Business travel
# 103903  103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight_Distance  Inflight_wifi_service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival_time_convenient  ...  Inflight_entertainment  \
# 0                                       4  ...                       5
# 1                                       2  ...                       1
# 2                                       2  ...                       5
# 3                                       5  ...                       2
# 4                                       3  ...                       3
# ...                                   ...  ...                     ...
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival_Delay_in_Minutes             satisfaction
# 0                           18.0  neutral or dissatisfied
# 1                            6.0  neutral or dissatisfied
# 2                            0.0                satisfied
# 3                            9.0  neutral or dissatisfied
# 4                            0.0                satisfied
# ...                          ...                      ...
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [103904 rows x 25 columns]

# %% [markdown]
# Menghilangkan data-data yang kosong

# %%
data = data.dropna()
data
# Out:
#             SR      id  Gender      Customer_Type  Age   Type_of_Travel  \
# 0            0   70172    Male     Loyal Customer   13  Personal Travel
# 1            1    5047    Male  disloyal Customer   25  Business travel
# 2            2  110028  Female     Loyal Customer   26  Business travel
# 3            3   24026  Female     Loyal Customer   25  Business travel
# 4            4  119299    Male     Loyal Customer   61  Business travel
# ...        ...     ...     ...                ...  ...              ...
# 103899  103899   94171  Female  disloyal Customer   23  Business travel
# 103900  103900   73097    Male     Loyal Customer   49  Business travel
# 103901  103901   68825    Male  disloyal Customer   30  Business travel
# 103902  103902   54173  Female  disloyal Customer   22  Business travel
# 103903  103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight_Distance  Inflight_wifi_service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival_time_convenient  ...  Inflight_entertainment  \
# 0                                       4  ...                       5
# 1                                       2  ...                       1
# 2                                       2  ...                       5
# 3                                       5  ...                       2
# 4                                       3  ...                       3
# ...                                   ...  ...                     ...
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival_Delay_in_Minutes             satisfaction
# 0                           18.0  neutral or dissatisfied
# 1                            6.0  neutral or dissatisfied
# 2                            0.0                satisfied
# 3                            9.0  neutral or dissatisfied
# 4                            0.0                satisfied
# ...                          ...                      ...
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [103594 rows x 25 columns]

# %% [markdown]
# Terdapat 310 data yang kosong

# %% [markdown]
# <h4>Mencoba untuk menghapus data duplikat(jika ada)</h4>

# %%
data = data.drop_duplicates()
data
# Out:
#             SR      id  Gender      Customer_Type  Age   Type_of_Travel  \
# 0            0   70172    Male     Loyal Customer   13  Personal Travel
# 1            1    5047    Male  disloyal Customer   25  Business travel
# 2            2  110028  Female     Loyal Customer   26  Business travel
# 3            3   24026  Female     Loyal Customer   25  Business travel
# 4            4  119299    Male     Loyal Customer   61  Business travel
# ...        ...     ...     ...                ...  ...              ...
# 103899  103899   94171  Female  disloyal Customer   23  Business travel
# 103900  103900   73097    Male     Loyal Customer   49  Business travel
# 103901  103901   68825    Male  disloyal Customer   30  Business travel
# 103902  103902   54173  Female  disloyal Customer   22  Business travel
# 103903  103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight_Distance  Inflight_wifi_service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival_time_convenient  ...  Inflight_entertainment  \
# 0                                       4  ...                       5
# 1                                       2  ...                       1
# 2                                       2  ...                       5
# 3                                       5  ...                       2
# 4                                       3  ...                       3
# ...                                   ...  ...                     ...
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival_Delay_in_Minutes             satisfaction
# 0                           18.0  neutral or dissatisfied
# 1                            6.0  neutral or dissatisfied
# 2                            0.0                satisfied
# 3                            9.0  neutral or dissatisfied
# 4                            0.0                satisfied
# ...                          ...                      ...
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [103594 rows x 25 columns]

# %% [markdown]
# tidak ada perubahan jumlah baris dalam data, sehingga data ini tidak memiliki duplikat

# %% [markdown]
# Kolom SR dan ID adalah kolom yang berhubungan dengan identitas pelanggan. Hal ini tidak akan mengganggu proses pemodelan. Sehingga variabel-variabel ini dihapus

# %%
data=data.drop("SR",axis=1)
data=data.drop("id",axis=1)

# %% [markdown]
# <h2>Data Exploration</h2>
# <h5>Mengelompokkan Data berdasarkan group umur</h5>

# %%
age_groups={
    "0-9":data.Age.loc[data.Age<10].shape[0],
    "10-19":data.Age.loc[(data.Age>10)&(data.Age<=20)].shape[0],
    "20-29":data.Age.loc[(data.Age>20)&(data.Age<=30)].shape[0],
    "30-39":data.Age.loc[(data.Age>30)&(data.Age<=40)].shape[0],
    "40-49":data.Age.loc[(data.Age>40)&(data.Age<=50)].shape[0],
    "50-59":data.Age.loc[(data.Age>50)&(data.Age<=60)].shape[0],
    "60-69":data.Age.loc[(data.Age>60)&(data.Age<=70)].shape[0],
    "70-79":data.Age.loc[(data.Age>70)&(data.Age<=80)].shape[0],
    "80-89":data.Age.loc[(data.Age>80)&(data.Age<=90)].shape[0],
}
print(age_groups)
# Out:
# {'0-9': 1884, '10-19': 8731, '20-29': 21363, '30-39': 21137, '40-49': 23133, '50-59': 18716, '60-69': 7194, '70-79': 738, '80-89': 17}

# %%
import numpy as np
x = np.array(list(age_groups.values()))
print("Age groups:")
for i in age_groups.keys():
    print(i,"\tPercentage:",age_groups[i]/x.sum()*100,"%")
# Out:
# Age groups:
# 0-9 	Percentage: 1.8306725097898224 %
# 10-19 	Percentage: 8.483865012194766 %
# 20-29 	Percentage: 20.758310417537142 %
# 30-39 	Percentage: 20.53870745192541 %
# 40-49 	Percentage: 22.478209749982994 %
# 50-59 	Percentage: 18.186234975173203 %
# 60-69 	Percentage: 6.990370507127379 %
# 70-79 	Percentage: 0.717110569121491 %
# 80-89 	Percentage: 0.016518807147785024 %

# %% [markdown]
# Lebih dari 80% Penumpang berumur 20-60. Kelompok umur difokuskan kepada penumpang berumumur diantara 20 dan 60 tahun

# %%
#mengidentifikasi penumpang tidak loyal berumumur 20-60
# data=data.loc[data["Customer_Type"]=="disloyal Customer"]
data=data.loc[(data.Age>=20)&(data.Age<=60)]
# data=data.drop("Customer_Type",axis=1)
data=data.dropna()

# %% [markdown]
# <h3>Mengeksplorasi data target(satisfaction)</h3>

# %%
count = data["satisfaction"].value_counts()
percent = 100*data["satisfaction"].value_counts(normalize=True)
df = pd.DataFrame({'jumlah sampel':count, 'persentase':percent.round(1)})
print(df)
count.plot(kind='bar', title="Satisfaction",rot=0)
# Out:
#                          jumlah sampel  persentase
# satisfaction
# neutral or dissatisfied          44372        51.7
# satisfied                        41493        48.3

# %% [markdown]
# <h4>Data kepuasan pelanggan menunjukkan bahwa data relatif berimbang. Pengurangan data tidak diperlukan untuk mengurangi bias pada pemodelan</h4>

# %% [markdown]
# <h2>Univariate Data analysis</h2>

# %%
data.describe().round(2)
# Out:
#             Age  Flight_Distance  Inflight_wifi_service  \
# count  85865.00         85865.00               85865.00
# mean      39.84          1239.69                   2.76
# std       11.42          1025.40                   1.35
# min       20.00            31.00                   0.00
# 25%       30.00           425.00                   2.00
# 50%       40.00           867.00                   3.00
# 75%       49.00          1846.00                   4.00
# max       60.00          4983.00                   5.00
#
#        Departure/Arrival_time_convenient  Ease_of_Online_booking  \
# count                           85865.00                85865.00
# mean                                3.00                    2.78
# std                                 1.53                    1.41
# min                                 0.00                    0.00
# 25%                                 2.00                    2.00
# 50%                                 3.00                    3.00
# 75%                                 4.00                    4.00
# max                                 5.00                    5.00
#
#        Gate_location  Food_and_drink  Online_boarding  Seat_comfort  \
# count       85865.00        85865.00         85865.00      85865.00
# mean            2.98            3.23             3.33          3.50
# std             1.29            1.32             1.34          1.31
# min             0.00            0.00             0.00          0.00
# 25%             2.00            2.00             2.00          3.00
# 50%             3.00            3.00             4.00          4.00
# 75%             4.00            4.00             4.00          5.00
# max             5.00            5.00             5.00          5.00
#
#        Inflight_entertainment  On-board_service  Leg_room_service  \
# count                85865.00          85865.00          85865.00
# mean                     3.41              3.42              3.40
# std                      1.32              1.28              1.31
# min                      0.00              0.00              0.00
# 25%                      2.00              3.00              2.00
# 50%                      4.00              4.00              4.00
# 75%                      5.00              4.00              4.00
# max                      5.00              5.00              5.00
#
#        Baggage_handling  Checkin_service  Inflight_service  Cleanliness  \
# count          85865.00         85865.00          85865.00     85865.00
# mean               3.66             3.33              3.66         3.33
# std                1.18             1.26              1.17         1.30
# min                1.00             0.00              0.00         0.00
# 25%                3.00             3.00              3.00         2.00
# 50%                4.00             3.00              4.00         3.00
# 75%                5.00             4.00              5.00         4.00
# max                5.00             5.00              5.00         5.00
#
#        Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes
# count                    85865.00                  85865.00
# mean                        14.74                     15.16
# std                         38.24                     38.75
# min                          0.00                      0.00
# 25%                          0.00                      0.00
# 50%                          0.00                      0.00
# 75%                         12.00                     13.00
# max                       1592.00                   1584.00

# %%
import matplotlib.pyplot as plt
data.hist(bins=50,figsize=(20,20))
plt.show()

# %% [markdown]
# Berdasarkan informasi dari dataset dan data yang terbaca di pandas, beberapa variabel numerik meliputi: Age, Flight_Distance, Departure_Delay_in_Minutes, dan Arrival_Delay_in_Minutes

# %%
numerical_features=["Age","Flight_Distance","Departure_Delay_in_Minutes","Arrival_Delay_in_Minutes"]
features=list(data.columns)
for i in numerical_features:
    features.remove(i)
data[features]
# Out:
#         Gender      Customer_Type   Type_of_Travel     Class  \
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 5       Female     Loyal Customer  Personal Travel       Eco
# 6         Male     Loyal Customer  Personal Travel       Eco
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#         Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 1                           3                                  2
# 2                           2                                  2
# 3                           2                                  5
# 5                           3                                  4
# 6                           2                                  4
# ...                       ...                                ...
# 103899                      2                                  1
# 103900                      4                                  4
# 103901                      1                                  1
# 103902                      1                                  1
# 103903                      1                                  3
#
#         Ease_of_Online_booking  Gate_location  Food_and_drink  \
# 1                            3              3               1
# 2                            2              2               5
# 3                            5              5               2
# 5                            2              1               1
# 6                            2              3               2
# ...                        ...            ...             ...
# 103899                       2              3               2
# 103900                       4              4               2
# 103901                       1              3               4
# 103902                       1              5               1
# 103903                       3              3               1
#
#         Online_boarding  Seat_comfort  Inflight_entertainment  \
# 1                     3             1                       1
# 2                     5             5                       5
# 3                     2             2                       2
# 5                     2             1                       1
# 6                     2             2                       2
# ...                 ...           ...                     ...
# 103899                2             2                       2
# 103900                4             5                       5
# 103901                1             5                       4
# 103902                1             1                       1
# 103903                1             1                       1
#
#         On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 5                      3                 4                 4                4
# 6                      3                 3                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight_service  Cleanliness             satisfaction
# 1                      4            1  neutral or dissatisfied
# 2                      4            5                satisfied
# 3                      4            2  neutral or dissatisfied
# 5                      4            1  neutral or dissatisfied
# 6                      5            2  neutral or dissatisfied
# ...                  ...          ...                      ...
# 103899                 3            2  neutral or dissatisfied
# 103900                 5            4                satisfied
# 103901                 5            4  neutral or dissatisfied
# 103902                 4            1  neutral or dissatisfied
# 103903                 3            1  neutral or dissatisfied
#
# [85865 rows x 19 columns]

# %% [markdown]
# Variabel Gender, Customer_Type, Type_of_Travel, Class, dan satisfaction merupakan variabel numerik yang memberikan nilai data non-numerik. Sehingga variabel-variabel tersebut harus di encode terlebih dahulu(Tahapan Encoding di bawah)

# %% [markdown]
# <h2>Exploratory Data - Numerical Features</h2>

# %%
data[numerical_features].hist()
plt.show()

# %% [markdown]
# Variabel Age relatif rata, sedangkan variabel numerik lainnya memiliki kecenderungan left-skewed.

# %% [markdown]
# <h2>Mengidentifikasi outlier pada variabel-variabel numerik</h2>
# outlier diidentifikasi menggunakan boxplot

# %%
import seaborn as sns
sns.boxplot(data[numerical_features])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p>Berdasarkan grafik di atas, terdapat 3 variabel numerik yang memiliki outlier. Variabel tersebut meliputi: Flight_Distance, Departure_Delay_in_Minutes dan Arrival_Delay_in_Minutes</p>
# <p>Data outlier ini dihilangkan dengan menggunakan metode 1.5 interquantile range (IQR)</p>

# %%
Q1 = data[numerical_features].quantile(0.25)
Q3 = data[numerical_features].quantile(0.75)
IQR=Q3-Q1
data=data[~((data[numerical_features]<(Q1-1.5*IQR))|(data[numerical_features]>(Q3+1.5*IQR))).any(axis=1)]
data
# Out:
#         Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 5       Female     Loyal Customer   26  Personal Travel       Eco
# 6         Male     Loyal Customer   47  Personal Travel       Eco
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight_Distance  Inflight_wifi_service  \
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 5                  1180                      3
# 6                  1276                      2
# ...                 ...                    ...
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival_time_convenient  Ease_of_Online_booking  \
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 5                                       4                       2
# 6                                       4                       2
# ...                                   ...                     ...
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate_location  ...  Inflight_entertainment  On-board_service  \
# 1                   3  ...                       1                 1
# 2                   2  ...                       5                 4
# 3                   5  ...                       2                 2
# 5                   1  ...                       1                 3
# 6                   3  ...                       2                 3
# ...               ...  ...                     ...               ...
# 103899              3  ...                       2                 3
# 103900              4  ...                       5                 5
# 103901              3  ...                       4                 3
# 103902              5  ...                       1                 4
# 103903              3  ...                       1                 1
#
#         Leg_room_service  Baggage_handling  Checkin_service  Inflight_service  \
# 1                      5                 3                1                 4
# 2                      3                 4                4                 4
# 3                      5                 3                1                 4
# 5                      4                 4                4                 4
# 6                      3                 4                3                 5
# ...                  ...               ...              ...               ...
# 103899                 1                 4                2                 3
# 103900                 5                 5                5                 5
# 103901                 2                 4                5                 5
# 103902                 5                 1                5                 4
# 103903                 1                 4                4                 3
#
#         Cleanliness  Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  \
# 1                 1                           1                       6.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 5                 1                           0                       0.0
# 6                 2                           9                      23.0
# ...             ...                         ...                       ...
# 103899            2                           3                       0.0
# 103900            4                           0                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
# 103903            1                           0                       0.0
#
#                    satisfaction
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 5       neutral or dissatisfied
# 6       neutral or dissatisfied
# ...                         ...
# 103899  neutral or dissatisfied
# 103900                satisfied
# 103901  neutral or dissatisfied
# 103902  neutral or dissatisfied
# 103903  neutral or dissatisfied
#
# [72001 rows x 23 columns]

# %% [markdown]
# <p>setelah pembersihan data-data outlier menggunakan outlier, terdapat 72001 data. Variabel target kembali dihitung kembali untuk mengantisipasi data yang kurang seimbang</p>

# %%
count = data["satisfaction"].value_counts()
percent = 100*data["satisfaction"].value_counts(normalize=True)
df = pd.DataFrame({'jumlah sampel':count, 'persentase':percent.round(1)})
print(df)
count.plot(kind='bar', title="Satisfaction",rot=0);
# Out:
#                          jumlah sampel  persentase
# satisfaction
# neutral or dissatisfied          36294        50.4
# satisfied                        35707        49.6

# %% [markdown]
# <h4>Data kepuasan berimbang setelah 1.5xIQR</h4>

# %% [markdown]
# <h2>Data Preprocessing</h2>
# <h3>Encoding Categorical Features</h3>
# <p>Terdapat beberapa variabel kategorikal memberikan nilai keterangan. Hal ini tidak dapat dimodelkan. Oleh karena itu, variabel-variabel perlu dilakukan encoding agar dapat diproses oleh algoritma pemodelan.</p>
# <p>Variabel Gender, Type_of_Travel, Class, dan Customer_Type dilakukan one-hot encoding karena nilai datanya berupa keterangan. Sedangkan, nilai-nilai data dalam variabel Satisfaction ditransformasi ke angka biner(0 dan 1) karena datanya hanya dua dan lebih mudah dilakukan untuk binary classification</p>

# %%
from sklearn.preprocessing import  OneHotEncoder
from sklearn.preprocessing import LabelEncoder
data = pd.concat([data, pd.get_dummies(data['Gender'], prefix='Gender')],axis=1)
data = pd.concat([data, pd.get_dummies(data['Type_of_Travel'], prefix='Travel')],axis=1)
data = pd.concat([data, pd.get_dummies(data['Class'], prefix='Class')],axis=1)
data = pd.concat([data, pd.get_dummies(data['Customer_Type'], prefix='Customer_Type')],axis=1)

le = LabelEncoder()
data["satisfaction"]=le.fit_transform(data["satisfaction"])
data.drop(['Gender',"Type_of_Travel","Class","Customer_Type"],axis=1,inplace=True)

# %%
data
# Out:
#         Age  Flight_Distance  Inflight_wifi_service  \
# 1        25              235                      3
# 2        26             1142                      2
# 3        25              562                      2
# 5        26             1180                      3
# 6        47             1276                      2
# ...     ...              ...                    ...
# 103899   23              192                      2
# 103900   49             2347                      4
# 103901   30             1995                      1
# 103902   22             1000                      1
# 103903   27             1723                      1
#
#         Departure/Arrival_time_convenient  Ease_of_Online_booking  \
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 5                                       4                       2
# 6                                       4                       2
# ...                                   ...                     ...
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate_location  Food_and_drink  Online_boarding  Seat_comfort  \
# 1                   3               1                3             1
# 2                   2               5                5             5
# 3                   5               2                2             2
# 5                   1               1                2             1
# 6                   3               2                2             2
# ...               ...             ...              ...           ...
# 103899              3               2                2             2
# 103900              4               2                4             5
# 103901              3               4                1             5
# 103902              5               1                1             1
# 103903              3               1                1             1
#
#         Inflight_entertainment  ...  satisfaction  Gender_Female  Gender_Male  \
# 1                            1  ...             0          False         True
# 2                            5  ...             1           True        False
# 3                            2  ...             0           True        False
# 5                            1  ...             0           True        False
# 6                            2  ...             0          False         True
# ...                        ...  ...           ...            ...          ...
# 103899                       2  ...             0           True        False
# 103900                       5  ...             1          False         True
# 103901                       4  ...             0          False         True
# 103902                       1  ...             0           True        False
# 103903                       1  ...             0          False         True
#
#         Travel_Business travel  Travel_Personal Travel  Class_Business  \
# 1                         True                   False            True
# 2                         True                   False            True
# 3                         True                   False            True
# 5                        False                    True           False
# 6                        False                    True           False
# ...                        ...                     ...             ...
# 103899                    True                   False           False
# 103900                    True                   False            True
# 103901                    True                   False            True
# 103902                    True                   False           False
# 103903                    True                   False            True
#
#         Class_Eco  Class_Eco Plus  Customer_Type_Loyal Customer  \
# 1           False           False                         False
# 2           False           False                          True
# 3           False           False                          True
# 5            True           False                          True
# 6            True           False                          True
# ...           ...             ...                           ...
# 103899       True           False                         False
# 103900      False           False                          True
# 103901      False           False                         False
# 103902       True           False                         False
# 103903      False           False                          True
#
#         Customer_Type_disloyal Customer
# 1                                  True
# 2                                 False
# 3                                 False
# 5                                 False
# 6                                 False
# ...                                 ...
# 103899                             True
# 103900                            False
# 103901                             True
# 103902                             True
# 103903                            False
#
# [72001 rows x 28 columns]

# %% [markdown]
# <h2>Test-train split</h2>

# %% [markdown]
# Data di bagi menjadi data training 80% dan data test 20%

# %%
from sklearn.model_selection import train_test_split

X = data.drop("satisfaction",axis=1)
y = data['satisfaction']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)

# %%
print(f'Total # of sample in whole dataset: {len(X)}')
print(f'Total # of sample in train dataset: {len(X_train)}')
print(f'Total # of sample in test dataset: {len(X_test)}')
# Out:
# Total # of sample in whole dataset: 72001
# Total # of sample in train dataset: 57600
# Total # of sample in test dataset: 14401

# %% [markdown]
# <h2>Standard Scaling training numerical features </h2>
# <p>Data training dilakukan standard scaling untuk mempercepat proses pembelajaran. proses scaling data training dan data test dilakukan secara terpisah</p>

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
numerical_features=["Age","Flight_Distance","Departure_Delay_in_Minutes","Arrival_Delay_in_Minutes"]
scaler.fit(X_train[numerical_features])
X_train[numerical_features] = scaler.transform(X_train.loc[:, numerical_features])
X_train[numerical_features].describe().round(2)
# Out:
#             Age  Flight_Distance  Departure_Delay_in_Minutes  \
# count  57600.00         57600.00                    57600.00
# mean       0.00            -0.00                        0.00
# std        1.00             1.00                        1.00
# min       -1.74            -1.18                       -0.51
# 25%       -0.86            -0.80                       -0.51
# 50%        0.01            -0.36                       -0.51
# 75%        0.80             0.60                        0.08
# max        1.76             2.70                        3.93
#
#        Arrival_Delay_in_Minutes
# count                  57600.00
# mean                      -0.00
# std                        1.00
# min                       -0.52
# 25%                       -0.52
# 50%                       -0.52
# 75%                        0.07
# max                        4.22

# %% [markdown]
# <h3>Model Development</h3>
# Dilakukan 3 fitting model: KNN, Random Forest dan AdaBoosting

# %%
# Siapkan dataframe untuk analisis model
models = pd.DataFrame(index=['train_acc', 'test_acc'],
                      columns=['KNN', 'RandomForest', 'Boosting'])

# %% [markdown]
# Algoritma KNN membandingkan jarak satu sampel ke sampel pelatihan lain dengan memilih sejumlah k tetangga terdekat.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error

knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train, y_train)

models.loc['train_acc','KNN'] = knn.score(X_train,y_train)
print(models)
# Out:
#                 KNN RandomForest Boosting
# train_acc  0.934427          NaN      NaN
# test_acc        NaN          NaN      NaN

# %% [markdown]
# Algoritma Random forest menggunakan beberapa model decision tree (pengambilan keputusan berdasarkan kondisional) yang independen dan digabung menjadi satu kesatuan (bagging).

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100,max_depth=None,)
rf.fit(X_train,y_train)
models.loc['train_acc','RandomForest'] = rf.score(X_train,y_train)
print(models)
# Out:
#                 KNN RandomForest Boosting
# train_acc  0.934427          1.0      NaN
# test_acc        NaN          NaN      NaN

# %% [markdown]
# Algoritma Boosting memiliki pendekatan ensemble yang mirip dengan algoritma random forest. Metode ini memanfaatkan penggabungan model dengan model terbaru memperbaiki model sebelumnya hingga menciptakan model yang lebih baik. Pada algoritma Ada Boost, Awalnya, semua kasus dalam data latih memiliki weight atau bobot yang sama. Setiap tahap, bobot akan dirubah bergantung ketepatannya, tahapan ini terus dilakukan hingga model mencapai akurasi yang diinginkan.

# %%
from sklearn.ensemble import AdaBoostClassifier

boosting = AdaBoostClassifier(learning_rate=0.1, random_state=55)
boosting.fit(X_train, y_train)
models.loc['train_acc','Boosting'] = boosting.score(X_train,y_train)
print(models)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#                 KNN RandomForest  Boosting
# train_acc  0.934427          1.0  0.902743
# test_acc        NaN          NaN       NaN

# %% [markdown]
# Algoritma Random Forest memberikan score tertinggi diantara algoritma lainnya

# %% [markdown]
# <h2>Standard Scaling test numerical features </h2>
# data test dilakukan standard scaling secara terpisah dengan data training

# %%
X_test.loc[:, numerical_features] = scaler.transform(X_test[numerical_features])
# Out:
# <ipython-input-25-0615151fc0c1>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.29999868 -1.03806414  0.00967399 ... -0.60150659 -1.56193321
#   0.88278911]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_test.loc[:, numerical_features] = scaler.transform(X_test[numerical_features])
# <ipython-input-25-0615151fc0c1>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.04325622 -0.70706998  1.01416425 ...  1.19896838 -0.27553267
#  -0.04354451]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_test.loc[:, numerical_features] = scaler.transform(X_test[numerical_features])
# <ipython-input-25-0615151fc0c1>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.51332835 -0.51332835  1.11619566 ... -0.51332835 -0.51332835
#  -0.51332835]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_test.loc[:, numerical_features] = scaler.transform(X_test[numerical_features])

# %% [markdown]
# <h3>Model Evaluation</h3>

# %%
#model evaluation
acc = pd.DataFrame()
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score
model_dict = {'KNN': knn, "Ada Boosting":boosting,'RF': rf}
for name, model in model_dict.items():
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    # acc.loc[name, 'Accuracy_train'] = accuracy_score(y_true=y_train,y_pred=y_pred_train)
    # acc.loc[name, "Precision_train"] = precision_score(y_true=y_train,y_pred=y_pred_train)
    # acc.loc[name, "Recall_train"] = recall_score(y_true=y_train,y_pred=y_pred_train)
    # acc.loc[name, "F1_score_train"] = f1_score(y_true=y_train,y_pred=y_pred_train)
    acc.loc[name, 'Accuracy_test'] = accuracy_score(y_true=y_test,y_pred=y_pred_test)
    acc.loc[name, "Precision_test"] = precision_score(y_true=y_test,y_pred=y_pred_test)
    acc.loc[name, "Recall_test"] = recall_score(y_true=y_test,y_pred=y_pred_test)
    acc.loc[name, "F1_score_test"] = f1_score(y_true=y_test,y_pred=y_pred_test)

acc
# Out:
#               Accuracy_test  Precision_test  Recall_test  F1_score_test
# KNN                0.926047        0.946758     0.900042       0.922809
# Ada Boosting       0.902854        0.898120     0.904849       0.901472
# RF                 0.960905        0.969561     0.950233       0.959800

# %% [markdown]
# Algoritma Randomforest pada data test memberikan nilai peforma yang sangat baik

# %% [markdown]
# <h3>Hypertuning Parameters</h3>
# <h4>Menggunakan GridSearchCV</h4>
# Hypertuning parameter dilakukan untuk mencari parameter yang lebih baik dibandingkan parameter yang digunakan pada model

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50,100,200, 500],
    'max_features': ['sqrt', 'log2'],
    'max_depth' : [None],
    'criterion' :['gini', 'entropy']
}
CV_rfc = GridSearchCV(estimator=rf, param_grid=param_grid, cv= 5,verbose=5)
CV_rfc.fit(X_train, y_train)
CV_rfc.best_params_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.957 total time=   3.1s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.961 total time=   2.8s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.960 total time=   3.9s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.959 total time=   4.3s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.962 total time=   2.9s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.958 total time=   6.5s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.961 total time=   6.5s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.959 total time=   6.5s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.959 total time=   6.3s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.962 total time=   5.9s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.959 total time=  12.2s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.961 total time=  12.4s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.959 total time=  12.6s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.961 total time=  12.6s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.962 total time=  12.5s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.959 total time=  30.9s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.960 total time=  31.5s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.959 total time=  30.6s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.960 total time=  30.9s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.962 total time=  32.3s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50;, score=0.958 total time=   2.6s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50;, score=0.958 total time=   2.6s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50;, score=0.957 total time=   2.6s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50;, score=0.958 total time=   3.6s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=50;, score=0.960 total time=   2.5s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100;, score=0.958 total time=   5.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100;, score=0.959 total time=   6.2s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100;, score=0.958 total time=   5.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100;, score=0.960 total time=   5.4s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=100;, score=0.961 total time=   5.8s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=200;, score=0.960 total time=  12.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=200;, score=0.961 total time=  11.3s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=200;, score=0.959 total time=  10.5s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=200;, score=0.960 total time=  11.5s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=200;, score=0.961 total time=  11.2s
# [CV 1/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=500;, score=0.959 total time=  28.0s
# [CV 2/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=500;, score=0.960 total time=  28.1s
# [CV 3/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=500;, score=0.958 total time=  28.0s
# [CV 4/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=500;, score=0.959 total time=  28.1s
# [CV 5/5] END criterion=gini, max_depth=None, max_features=log2, n_estimators=500;, score=0.961 total time=  28.4s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.959 total time=   3.3s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.960 total time=   3.0s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.960 total time=   2.9s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.959 total time=   3.4s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.961 total time=   3.6s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.960 total time=   5.8s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.960 total time=   6.8s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.959 total time=   5.8s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.960 total time=   6.9s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.961 total time=   5.9s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.961 total time=  12.7s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.962 total time=  12.7s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.959 total time=  12.6s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.961 total time=  12.4s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.962 total time=  12.5s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.961 total time=  32.1s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.961 total time=  31.1s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.960 total time=  31.0s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.960 total time=  30.7s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=500;, score=0.963 total time=  30.7s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50;, score=0.958 total time=   3.3s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50;, score=0.959 total time=   2.6s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50;, score=0.958 total time=   2.6s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50;, score=0.959 total time=   2.6s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=50;, score=0.957 total time=   3.1s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100;, score=0.958 total time=   5.7s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100;, score=0.960 total time=   5.1s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100;, score=0.958 total time=   6.3s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100;, score=0.959 total time=   5.2s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=100;, score=0.961 total time=   6.1s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=200;, score=0.958 total time=  10.1s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=200;, score=0.960 total time=  11.2s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=200;, score=0.959 total time=  22.1s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=200;, score=0.960 total time=  11.5s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=200;, score=0.961 total time=  10.3s
# [CV 1/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=500;, score=0.958 total time=  28.1s
# [CV 2/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=500;, score=0.959 total time=  28.8s
# [CV 3/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=500;, score=0.959 total time=  28.6s
# [CV 4/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=500;, score=0.959 total time=  28.0s
# [CV 5/5] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=500;, score=0.961 total time=  29.1s
# {'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'n_estimators': 200}

# %% [markdown]
# <h3>Fitting data dengan parameter hasil GridSeachCV</h3>
# Hasil parameter terbaik dari hyperparameter tuning dengan GridSeachCV diset ke parameter model dan diukur kembali performanya.

# %%
print(CV_rfc.best_params_)
best_params=CV_rfc.best_params_
knn = RandomForestClassifier(criterion=best_params['criterion'],max_depth=best_params['max_depth'],
                            max_features=best_params['max_features'],n_estimators=best_params['n_estimators'])
knn.fit(X_train,y_train)
model_dict_ = {'RF_grid_search': knn}
acc1 = pd.DataFrame()


for name, model in model_dict_.items():
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    # acc.loc[name, 'Accuracy_train'] = accuracy_score(y_true=y_train,y_pred=y_pred_train)
    # acc.loc[name, "Precision_train"] = precision_score(y_true=y_train,y_pred=y_pred_train)
    # acc.loc[name, "Recall_train"] = recall_score(y_true=y_train,y_pred=y_pred_train)
    # acc.loc[name, "F1_score_train"] = f1_score(y_true=y_train,y_pred=y_pred_train)
    acc.loc[name, 'Accuracy_test'] = accuracy_score(y_true=y_test,y_pred=y_pred_test)
    acc.loc[name, "Precision_test"] = precision_score(y_true=y_test,y_pred=y_pred_test)
    acc.loc[name, "Recall_test"] = recall_score(y_true=y_test,y_pred=y_pred_test)
    acc.loc[name, "F1_score_test"] = f1_score(y_true=y_test,y_pred=y_pred_test)
acc
# Out:
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
#                 Accuracy_test  Precision_test  Recall_test  F1_score_test
# KNN                  0.926047        0.946758     0.900042       0.922809
# Ada Boosting         0.902854        0.898120     0.904849       0.901472
# RF                   0.960905        0.969561     0.950233       0.959800
# RF_grid_search       0.961530        0.971367     0.949668       0.960395

# %% [markdown]
# parameter hasil GridSeachCV memberikan hasil yang sedikit lebih baik

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(rf,X_test,y_test,display_labels=['neutral or dissatisfied','satisfied'])
plt.show()

# %%
pip freeze > requirements.txt
